# %% [markdown]
# # Contar vazios mês (cvm)

# %%
! python3 -m pip install unidecode
# Out:
# Requirement already satisfied: unidecode in /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (1.1.1)
# You are using pip version 10.0.1, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import sys
import os
from os.path import join
from os import listdir as ld
sys.path.append(join('/',*os.getcwd().split('/')[:-1], 'lib'))

# %%
# %matplotlib inline
import pandas as pd
import of_proc
import mainlib
from os import listdir as ld
from mainlib import dframe,fasorial
from matplotlib import pyplot as plt
from of_proc import pdump, pload, dk, daterange
# Out:
# Using TensorFlow backend.

# %% [markdown]
# l__________________________________________________________________________________________________________________________________________________

# %%
json_file = '../../info/info-LIGHT.json'
data = dframe(json_file).data
dp = dframe(json_file).dateparser

# %%
data['paths']['lista2']
# Out:
# '/home/ubuntu/data/data/maio_2019/setembro/lista-cad-pnt-20190820.csv'

# %% [markdown]
# ##### Lista 1 ou lista 2

# %%
#LISTA = data['paths']['lista2']
LISTA = '/home/ubuntu/data/data/maio_2019/setembro/lista-cad-pnt-20190820-faltantes.csv'

# %% [markdown]
# ##### Dados de lista 1 ou lista 2

# %%
#MM =   '/home/ubuntu/data/data/maio_2019/setembro/mm/csv/'
MM =  '/home/ubuntu/data/data/maio_2019/setembro/mm/csv_complementar/'

# %%
lista = pd.read_csv(LISTA, names = data['lista2']['columns'],index_col=[0],parse_dates=[3,4,5,7,8,9,10], date_parser =dp, skiprows=[0])
lista['data_fim'] = lista['data_fim'].apply(dp)

# %%
ddirs_fas = pload('../../pickles/ddirs_fas.pkl')

# %% [markdown]
# l__________________________________________________________________________________________________________________________________________________

# %% [markdown]
# #### Leituras faltando - Fasorial

# %%
faso = fasorial(json_file)
erros = []
emp = {}
emp_porc = {}
faso=fasorial(json_file)
print(len(ddirs_fas))
for n,(k,v) in enumerate(ddirs_fas.items()):
    try:
        l = lista[[4,5,6,7]].loc[k]
        if type(l) == pd.Series:
            ddays = dict(l)        
        elif type(ddays) == pd.DataFrame:
            ddays = dict(l.groupby('cliente').first().iloc[0])
        else:
            print('Erro desconhecido: ', k)
        dff = pd.read_csv(v,sep=';',date_parser = dp,parse_dates=[5],names=data['fasorial']['columns'],index_col=5)
        faso.split_months(df=dff,ddays=ddays,json_file=json_file)
        emp[k] = {}
        emp_porc[k] = {}
        for y in faso.months.values():
            for number,dat in y.items():            
                new_df = dat.df.iloc[:,0].resample('15min').first()
                emp[k][number]=new_df.isna().sum()
                emp_porc[k][number]=new_df.isna().sum()/len(new_df)
        print('*&!@#--> ', n,k, emp[k][number])
    except Exception as e:
        print(e)
        erros.append(k)
# Out:
# 1426
# 'BT2A400076589'
# 'BT2A400085952'
# 'BT2A400086240'
# 'BT2A400091987'
# 'BT2A400104752'
# 'BT2A400104884'
# 'BT2A400113506'
# 'BT2A400114162'
# 'BT2A400120332'
# 'BT2A400120898'
# 'BT2A400132810'
# 'BT2A400132870'
# 'BT2A400136450'
# 'BT2A400260487'
# 'BT2A400288195'
# 'BT2A400291188'
# 'BT2A400300110'
# 'BT2A400352837'
# 'BT2A400357847'
# 'BT2A400391131'
# 'BT2A400402672'
# 'BT2A400405116'
# 'BT2A410001280'
# 'BT2A410001603'
# 'BT2A410018693'
# 'BT2A410032723'
# 'BT2A410040647'
# 'BT2A410047095'
# 'BT2A410062626'
# 'BT2A410076151'
# 'BT2A410083876'
# 'BT2A410085766'
# 'BT2A410100693'
# 'BT2A410122181'
# 'BT2A410134082'
# 'BT2A410134354'
# 'BT2A410151342'
# 'BT2A410151989'
# 'BT2A410183430'
# 'BT2A410204435'
# 'BT2A410213480'
# 'BT2A410217918'
# 'BT2A410217995'
# 'BT2A410228107'
# 'BT2A410231166'
# 'BT2A410268231'
# 'BT2A410269391'
# 'BT2A410283913'
# 'BT2A410290781'
# 'BT2A410296702'
# 'BT2A410298496'
# 'BT2A410303893'
# 'BT2A410310853'
# 'BT2A410313860'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  54 BT2A410315584 1
# 'BT2A410320324'
# 'BT2A410369719'
# 'BT2A410369803'
# 'BT2A410391840'
# 'BT2A410401466'
# 'BT2A410424861'
# 'BT2A410442647'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  62 BT2A410444087 333
# Erro desconhecido:  BT2A410457345
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  63 BT2A410457345 2
# 'BT2A410471219'
# 'BT2A410476676'
# 'BT2A410483051'
# 'BT2A410484082'
# 'BT2A410496596'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  69 BT2A410496740 2
# 'BT2A410518610'
# 'BT2A410521023'
# 'BT2A410535875'
# 'BT2A410552998'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  74 BT2A410564455 3
# 'BT2A410567379'
# {4: Timestamp('2019-04-27 00:00:00'), 5: Timestamp('2019-05-29 00:00:00'), 6: Timestamp('2019-06-28 00:00:00'), 7: Timestamp('2019-07-29 00:00:00')}
# *&!@#-->  76 BT2A410574718 56
# 'BT2A410577169'
# 'BT2A410603572'
# 'BT2A410616391'
# 'BT2A410626256'
# 'BT2A410627749'
# 'BT2A410630673'
# 'BT2A410635509'
# 'BT2A410641775'
# 'BT2A410650333'
# 'BT2A410656564'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  87 BT2A410661427 10
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  88 BT2A410711734 4
# 'BT2A410740880'
# 'BT2A410748368'
# 'BT2A410750319'
# 'BT2A410754380'
# 'BT2A410754661'
# 'BT2A410754689'
# 'BT2A410755433'
# 'BT2A410760711'
# 'BT2A410773116'
# 'BT2A410774805'
# 'BT2A410782928'
# 'BT2A410797231'
# 'BT2A410812177'
# 'BT2A410816343'
# 'BT2A410820365'
# 'BT2A410826331'
# 'BT2A410829750'
# 'BT2A410859833'
# 'BT2A410864725'
# 'BT2A410865129'
# 'BT2A410874753'
# 'BT2A410912472'
# 'BT2A410913928'
# 'BT2A410918961'
# 'BT2A410951868'
# 'BT2A410958963'
# 'BT2A410981946'
# 'BT2A410984302'
# 'BT2A411035426'
# 'BT2A411045571'
# 'BT2A411050698'
# {4: Timestamp('2019-04-27 00:00:00'), 5: Timestamp('2019-05-29 00:00:00'), 6: Timestamp('2019-06-28 00:00:00'), 7: Timestamp('2019-07-29 00:00:00')}
# *&!@#-->  120 BT2A411062569 72
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  121 BT2A411063546 11
# 'BT2A411064013'
# 'BT2A411069667'
# 'BT2A411071225'
# 'BT2A411079354'
# 'BT2A411085606'
# 'BT2A411086885'
# 'BT2A411089754'
# 'BT2A411095283'
# 'BT2A411095610'
# 'BT2A411102510'
# 'BT2A411103491'
# 'BT2A411103912'
# 'BT2A411127823'
# 'BT2A411133431'
# 'BT2A411136273'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  137 BT2A411136693 30
# 'BT2A411138806'
# 'BT2A411145184'
# 'BT2A411170450'
# 'BT2A411172929'
# 'BT2A411173700'
# 'BT2A411174964'
# 'BT2A411182189'
# 'BT2A411185913'
# 'BT2A411188378'
# 'BT2A411193452'
# 'BT2A411193803'
# 'BT2A411193901'
# 'BT2A411193906'
# 'BT2A411212104'
# 'BT2A411212273'
# 'BT2A411212274'
# 'BT2A411212456'
# 'BT2A411214944'
# 'BT2A411215090'
# 'BT2A411220633'
# 'BT2A411220783'
# 'BT2A411227193'
# 'BT2A411228754'
# 'BT2A411233564'
# 'BT2A411241138'
# 'BT2A411256132'
# 'BT2A411268564'
# 'BT2A411270498'
# 'BT2A411290267'
# 'BT2A411292733'
# 'BT2A411303569'
# 'BT2A411304140'
# 'BT2A411309955'
# 'BT2A411311698'
# 'BT2A411314941'
# 'BT2A411314945'
# 'BT2A411324288'
# 'BT2A411329920'
# 'BT2A411353120'
# 'BT2A411356498'
# 'BT2A411358998'
# 'BT2A411367522'
# 'BT2A411395036'
# 'BT2A411396152'
# 'BT2A411415341'
# 'BT2A411427990'
# 'BT2A411428531'
# 'BT2A411442455'
# 'BT2A411444175'
# 'BT2A411452925'
# {4: Timestamp('2019-04-27 00:00:00'), 5: Timestamp('2019-05-29 00:00:00'), 6: Timestamp('2019-06-28 00:00:00'), 7: Timestamp('2019-07-29 00:00:00')}
# *&!@#-->  188 BT2A411453683 79
# 'BT2A411456287'
# 'BT2A411458079'
# 'BT2A411475131'
# 'BT2A411482615'
# 'BT2A411489652'
# 'BT2A411505201'
# 'BT2A411518477'
# 'BT2A411523302'
# 'BT2A411527383'
# 'BT2A411528408'
# 'BT2A411558030'
# 'BT2A411568437'
# 'BT2A411568489'
# 'BT2A411571775'
# 'BT2A411572567'
# 'BT2A411577967'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  205 BT2A411580720 2
# 'BT2A411612118'
# 'BT2A411615612'
# 'BT2A411618334'
# 'BT2A411621834'
# 'BT2A411623439'
# 'BT2A411630252'
# 'BT2A411644015'
# 'BT2A411645365'
# 'BT2A411650153'
# 'BT2A411650476'
# 'BT2A411655017'
# 'BT2A411655072'
# 'BT2A411655659'
# 'BT2A411658624'
# 'BT2A411659662'
# 'BT2A411659894'
# 'BT2A411659898'
# 'BT2A411660127'
# 'BT2A411660658'
# 'BT2A411661000'
# 'BT2A411669549'
# 'BT2A411682226'
# 'BT2A411683588'
# 'BT2A411684320'
# 'BT2A411692905'
# 'BT2A411693352'
# 'BT2A411713862'
# 'BT2A411721830'
# 'BT2A411722898'
# 'BT2A411736296'
# 'BT2A411783685'
# 'BT2A411785717'
# 'BT2A411788491'
# 'BT2A411794444'
# 'BT2A411819903'
# 'BT2A411841240'
# 'BT2A411855278'
# 'BT2A411863640'
# 'BT2A411882451'
# 'BT2A411911700'
# 'BT2A411920427'
# 'BT2A411932932'
# 'BT2A411957803'
# 'BT2A411969939'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  250 BT2A412008091 13
# 'BT2A412034789'
# 'BT2A412037254'
# 'BT2A412044492'
# 'BT2A412048024'
# 'BT2A412072721'
# 'BT2A412074110'
# 'BT2A412086419'
# 'BT2A412089976'
# 'BT2A412097308'
# 'BT2A412115894'
# 'BT2A412137612'
# 'BT2A412167259'
# 'BT2A412215776'
# 'BT2A412235629'
# 'BT2A412242395'
# 'BT2A412257832'
# 'BT2A412257898'
# 'BT2A412317894'
# 'BT2A412339162'
# {4: Timestamp('2019-04-27 00:00:00'), 5: Timestamp('2019-05-29 00:00:00'), 6: Timestamp('2019-06-28 00:00:00'), 7: Timestamp('2019-07-29 00:00:00')}
# *&!@#-->  270 BT2A412377295 43
# 'BT2A412390913'
# 'BT2A412392129'
# 'BT2A412428379'
# 'BT2A412432568'
# 'BT2A412438190'
# 'BT2A412454947'
# 'BT2A412457966'
# 'BT2A412461270'
# 'BT2A412465532'
# 'BT2A412480437'
# 'BT2A412489685'
# 'BT2A412508186'
# 'BT2A412519158'
# 'BT2A412527743'
# {4: Timestamp('2019-04-27 00:00:00'), 5: Timestamp('2019-05-29 00:00:00'), 6: Timestamp('2019-06-28 00:00:00'), 7: Timestamp('2019-07-29 00:00:00')}
# *&!@#-->  285 BT2A412538674 221
# {4: Timestamp('2019-04-25 00:00:00'), 5: Timestamp('2019-05-27 00:00:00'), 6: Timestamp('2019-06-26 00:00:00'), 7: Timestamp('2019-07-25 00:00:00')}
# *&!@#-->  286 BT2A412541235 14
# 'BT2A412543213'
# 'BT2A412550649'
# 'BT2A412598763'
# 'BT2A412619704'
# 'BT2A412622151'
# 'BT2A412636813'
# 'BT2A412637490'
# 'BT2A412637893'
# 'BT2A412658131'
# 'BT2A412665938'
# 'BT2A412669939'
# 'BT2A412674624'
# 'BT2A412678557'
# 'BT2A412703900'
# 'BT2A412703930'
# 'BT2A412713990'
# 'BT2A412714231'
# 'BT2A412721708'
# 'BT2A412741704'
# 'BT2A412744882'
# {4: Timestamp('2019-04-27 00:00:00'), 5: Timestamp('2019-05-29 00:00:00'), 6: Timestamp('2019-06-28 00:00:00'), 7: Timestamp('2019-07-29 00:00:00')}
# *&!@#-->  307 BT2A412758021 102
# 'BT2A412759418'
# 'BT2A412769899'
# 'BT2A412779441'
# 'BT2A412781564'
# 'BT2A412788667'
# 'BT2A412794172'
# 'BT2A412801054'
# 'BT2A412813278'
# 'BT2A412855882'
# 'BT2A412881927'
# 'BT2A412889274'
# 'BT2A412904002'
# 'BT2A412905869'
# 'BT2A412948600'
# 'BT2A412976586'
# 'BT2A412986267'
# 'BT2A412990455'
# 'BT2A413003055'
# 'BT2A413005505'
# 'BT2A413020761'
# 'BT2A413043134'
# 'BT2A413043833'
# 'BT2A413075265'
# 'BT2A413081315'
# 'BT2A413109222'
# 'BT2A413144489'
# 'BT2A413156192'
# 'BT2A413157002'
# 'BT2A413160639'
# 'BT2A413169428'
# 'BT2A413172110'
# 'BT2A413174976'
# 'BT2A413189775'
# 'BT2A413242657'
# 'BT2A413253638'
# 'BT2A413255013'
# 'BT2A413317324'
# 'BT2A413325780'
# 'BT2A413326043'
# 'BT2A413333039'
# 'BT2A413340947'
# 'BT2A413358426'
# 'BT2A413397815'
# 'BT2A413399504'
# 'BT2A413408475'
# 'BT2A413419789'
# 'BT2A413424398'
# 'BT2A413427484'
# {4: Timestamp('2019-04-27 00:00:00'), 5: Timestamp('2019-05-29 00:00:00'), 6: Timestamp('2019-06-28 00:00:00'), 7: Timestamp('2019-07-29 00:00:00')}
# *&!@#-->  356 BT2A413443943 128
# 'BT2A413447081'
# 'BT2A413475469'
# 'BT2A413477202'
# 'BT2A413491902'
# 'BT2A413494033'
# 'BT2A413494835'
# 'BT2A413501299'
# 'BT2A413512843'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  365 BT2A413528302 122
# 'BT2A413540844'
# 'BT2A413551703'
# 'BT2A413553219'
# 'BT2A413609671'
# 'BT2A413611209'
# 'BT2A413614950'
# 'BT2A413622108'
# 'BT2A413642837'
# 'BT2A413658133'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  375 BT2A413668708 13
# 'BT2A413669191'
# 'BT2A413695294'
# 'BT2A413699866'
# 'BT2A413708214'
# 'BT2A413709676'
# 'BT2A413726020'
# 'BT2A413739169'
# 'BT2A413746408'
# 'BT2A413755537'
# 'BT2A413757372'
# 'BT2A413763054'
# 'BT2A413770125'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  388 BT2A413776819 14
# 'BT2A413785709'
# 'BT2A413808048'
# 'BT2A413811762'
# 'BT2A413871181'
# 'BT2A413876080'
# 'BT2A414023619'
# 'BT2A414067258'
# 'BT2A414146648'
# 'BT2A414163952'
# 'BT2A414191407'
# 'BT2A414211457'
# 'BT2A414324503'
# 'BT2A414327293'
# 'BT2A414327296'
# 'BT2A414344217'
# 'BT2A414348442'
# 'BT2A414367448'
# 'BT2A414367449'
# 'BT2A414387177'
# 'BT2A414405209'
# 'BT2A414407935'
# 'BT2A414445698'
# 'BT2A414448180'
# 'BT2A414490860'
# 'BT2A414498242'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  414 BT2A414505502 14
# 'BT2A414509814'
# 'BT2A414509928'
# 'BT2A414511097'
# 'BT2A414518494'
# 'BT2A414525602'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  420 BT2A414526295 6
# 'BT2A414536702'
# 'BT2A414554483'
# {4: Timestamp('2019-04-27 00:00:00'), 5: Timestamp('2019-05-29 00:00:00'), 6: Timestamp('2019-06-28 00:00:00'), 7: Timestamp('2019-07-29 00:00:00')}
# *&!@#-->  423 BT2A414566994 28
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  424 BT2A414583015 14
# 'BT2A414583388'
# 'BT2A414604945'
# 'BT2A414607199'
# {4: Timestamp('2019-04-27 00:00:00'), 5: Timestamp('2019-05-29 00:00:00'), 6: Timestamp('2019-06-28 00:00:00'), 7: Timestamp('2019-07-29 00:00:00')}
# *&!@#-->  428 BT2A414610425 76
# 'BT2A414616917'
# 'BT2A414620469'
# 'BT2A414637815'
# 'BT2A414642567'
# 'BT2A414653673'
# 'BT2A414689818'
# 'BT2A414702812'
# 'BT2A414715328'
# 'BT2A414732662'
# 'BT2A414741036'
# 'BT2A414759031'
# 'BT2A414788784'
# 'BT2A414803326'
# 'BT2A414813321'
# 'BT2A414826320'
# 'BT2A414833048'
# 'BT2A414833050'
# 'BT2A414838723'
# 'BT2A414838812'
# 'BT2A414839185'
# 'BT2A414858954'
# 'BT2A414865002'
# 'BT2A414873095'
# 'BT2A414879939'
# 'BT2A414885946'
# 'BT2A420025502'
# 'BT2A420054001'
# 'BT2A420055854'
# 'BT2A420064068'
# 'BT2A420064391'
# 'BT2A420075274'
# 'BT2A420075911'
# 'BT2A420077978'
# {4: Timestamp('2019-04-27 00:00:00'), 5: Timestamp('2019-05-29 00:00:00'), 6: Timestamp('2019-06-28 00:00:00'), 7: Timestamp('2019-07-29 00:00:00')}
# *&!@#-->  462 BT2A420103194 19
# 'BT2A420119571'
# 'BT2A420121078'
# 'BT2A420130255'
# 'BT2A420135273'
# 'BT2A420148589'
# 'BT2A420161596'
# 'BT2A420162370'
# 'BT2A420162409'
# 'BT2A420162410'
# 'BT2A420162420'
# 'BT2A420162424'
# 'BT2A420162425'
# 'BT2A420162460'
# 'BT2A420187119'
# 'BT2A420198584'
# 'BT2A420200980'
# 'BT2A420205333'
# 'BT2A420219170'
# 'BT2A420226682'
# 'BT2A420231449'
# 'BT2A420238182'
# 'BT2A420239603'
# 'BT2A420248923'
# 'BT2A420262240'
# 'BT2A420267187'
# 'BT2A420269490'
# 'BT2A420272196'
# 'BT2A420280232'
# 'BT2A420281013'
# 'BT2A420293451'
# 'BT2A420297072'
# 'BT2A420301688'
# 'BT2A420313060'
# 'BT2A420313139'
# 'BT2A420313182'
# 'BT2A420313214'
# 'BT2A420336117'
# 'BT2A420340895'
# 'BT2A420368858'
# 'BT2A420370314'
# 'BT2A420373530'
# 'BT2A420384317'
# 'BT2A420386126'
# 'BT2A420387373'
# 'BT2A420392738'
# 'BT2A420399343'
# 'BT2A420423345'
# 'BT2A420429444'
# 'BT2A420430130'
# 'BT2A420435629'
# 'BT2A420438759'
# 'BT2A420449158'
# 'BT2A420451721'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  516 BT2A420475716 176
# 'BT2A420477736'
# 'BT2A420485961'
# 'BT2A420492569'
# 'BT2A420492586'
# 'BT2A420497054'
# 'BT2A420499659'
# 'BT2A420515786'
# 'BT2A420530092'
# 'BT2A420542183'
# 'BT2A420567171'
# 'BT2A420576543'
# 'BT2A420588423'
# 'BT2A420590317'
# 'BT2A420593100'
# 'BT2A420602212'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  532 BT2A420605940 16
# 'BT2A420611159'
# {4: Timestamp('2019-04-27 00:00:00'), 5: Timestamp('2019-05-29 00:00:00'), 6: Timestamp('2019-06-28 00:00:00'), 7: Timestamp('2019-07-29 00:00:00')}
# *&!@#-->  534 BT2A420613277 62
# 'BT2A420623980'
# 'BT2A420654896'
# 'BT2A420665622'
# 'BT2A420671390'
# 'BT2A420701209'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  540 BT2A420705641 9
# 'BT2A420716601'
# 'BT2A420755324'
# 'BT2A420758358'
# 'BT2A420766551'
# 'BT2A420788708'
# 'BT2A420806655'
# 'BT2A420823883'
# 'BT2A420877903'
# 'BT2A420892168'
# 'BT2A420909602'
# 'BT2A420912337'
# 'BT2A420915125'
# 'BT2A420923467'
# 'BT2A420929402'
# 'BT2A420939117'
# 'BT2A420946900'
# 'BT2A420976980'
# 'BT2A420989240'
# 'BT2A420998885'
# 'BT2A421011955'
# 'BT2A421022011'
# {4: Timestamp('2019-04-25 00:00:00'), 5: Timestamp('2019-05-27 00:00:00'), 6: Timestamp('2019-06-26 00:00:00'), 7: Timestamp('2019-07-25 00:00:00')}
# *&!@#-->  562 BT2A421042017 21
# 'BT2A421052825'
# 'BT2A421081253'
# 'BT2A421119199'
# 'BT2A421122290'
# 'BT2A421142677'
# 'BT2A421144885'
# 'BT2A421169197'
# 'BT2A421177693'
# 'BT2A421182268'
# 'BT2A421198227'
# 'BT2A421208548'
# 'BT2A421215867'
# 'BT2A421220005'
# 'BT2A421223454'
# 'BT2A421241983'
# 'BT2A421250758'
# 'BT2A421271844'
# 'BT2A421279577'
# 'BT2A421281184'
# 'BT2A421291222'
# 'BT2A421297780'
# 'BT2A421303010'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  585 BT2A421331411 14
# 'BT2A430044984'
# 'BTI400024830'
# 'BTI400047821'
# 'BTI400048534'
# 'BTI400048763'
# 'BTI400053350'
# 'BTI400054100'
# 'BTI400054739'
# 'BTI400054747'
# 'BTI400054755'
# 'BTI400054771'
# 'BTI400054780'
# 'BTI400054798'
# 'BTI400054801'
# 'BTI400054810'
# 'BTI400056162'
# 'BTI400060399'
# 'BTI400064262'
# 'BTI400064734'
# 'BTI400071560'
# 'BTI400073539'
# 'BTI400073652'
# 'BTI400077054'
# 'BTI400082538'
# 'BTI400083135'
# 'BTI400084328'
# 'BTI400085863'
# 'BTI400086150'
# 'BTI400086673'
# 'BTI400086681'
# 'BTI400087467'
# 'BTI400089397'
# 'BTI400091995'
# 'BTI400092045'
# 'BTI400094048'
# 'BTI400095370'
# 'BTI400099015'
# 'BTI400110582'
# 'BTI400113018'
# 'BTI400113140'
# 'BTI400113433'
# 'BTI400113484'
# 'BTI400114910'
# 'BTI400118192'
# 'BTI400118680'
# 'BTI400122599'
# 'BTI400129917'
# 'BTI400138312'
# 'BTI400152099'
# 'BTI400174866'
# 'BTI400181013'
# 'BTI400222615'
# 'BTI400235040'
# 'BTI400265519'
# 'BTI400267880'
# 'BTI400296112'
# 'BTI400297429'
# 'BTI400301507'
# 'BTI400313580'
# 'BTI400360775'
# 'BTI400376108'
# 'BTI410000588'
# 'BTI410001457'
# 'BTI410001718'
# 'BTI410005110'
# {4: Timestamp('2019-04-27 00:00:00'), 5: Timestamp('2019-05-29 00:00:00'), 6: Timestamp('2019-06-28 00:00:00'), 7: Timestamp('2019-07-29 00:00:00')}
# *&!@#-->  651 BTI410006819 44
# {4: Timestamp('2019-04-27 00:00:00'), 5: Timestamp('2019-05-29 00:00:00'), 6: Timestamp('2019-06-28 00:00:00'), 7: Timestamp('2019-07-29 00:00:00')}
# *&!@#-->  652 BTI410006988 44
# 'BTI410008216'
# 'BTI410008428'
# 'BTI410008433'
# 'BTI410009343'
# 'BTI410009410'
# 'BTI410011615'
# 'BTI410017492'
# 'BTI410018634'
# 'BTI410021054'
# 'BTI410021805'
# 'BTI410031266'
# 'BTI410045523'
# 'BTI410047942'
# 'BTI410049617'
# 'BTI410049730'
# 'BTI410062609'
# 'BTI410085371'
# 'BTI410086821'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  671 BTI410112094 1
# 'BTI410119113'
# 'BTI410122505'
# 'BTI410137172'
# 'BTI410137816'
# 'BTI410139989'
# 'BTI410141810'
# 'BTI410142176'
# 'BTI410155805'
# 'BTI410164402'
# 'BTI410164845'
# 'BTI410170662'
# 'BTI410190798'
# 'BTI410194241'
# 'BTI410197409'
# 'BTI410206521'
# 'BTI410217881'
# 'BTI410225952'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  689 BTI410226095 18
# 'BTI410228971'
# 'BTI410230473'
# 'BTI410237133'
# 'BTI410269345'
# 'BTI410274942'
# 'BTI410274946'
# 'BTI410274952'
# 'BTI410275140'
# 'BTI410277166'
# 'BTI410288884'
# 'BTI410292571'
# {4: Timestamp('2019-04-27 00:00:00'), 5: Timestamp('2019-05-29 00:00:00'), 6: Timestamp('2019-06-28 00:00:00'), 7: Timestamp('2019-07-29 00:00:00')}
# *&!@#-->  701 BTI410295093 22
# 'BTI410298157'
# 'BTI410298329'
# 'BTI410298633'
# 'BTI410299441'
# 'BTI410328119'
# 'BTI410328848'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  708 BTI410332762 53
# 'BTI410349814'
# 'BTI410350137'
# 'BTI410350149'
# 'BTI410356401'
# 'BTI410359663'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  714 BTI410359670 16
# 'BTI410360258'
# 'BTI410360627'
# 'BTI410361215'
# {4: Timestamp('2019-04-27 00:00:00'), 5: Timestamp('2019-05-29 00:00:00'), 6: Timestamp('2019-06-28 00:00:00'), 7: Timestamp('2019-07-29 00:00:00')}
# *&!@#-->  718 BTI410361683 723
# 'BTI410364444'
# 'BTI410364472'
# 'BTI410364481'
# 'BTI410365358'
# 'BTI410369282'
# 'BTI410394840'
# 'BTI410398601'
# 'BTI410412319'
# 'BTI410426420'
# 'BTI410431681'
# 'BTI410435527'
# 'BTI410437363'
# 'BTI410445661'
# 'BTI410446600'
# 'BTI410446616'
# 'BTI410446621'
# 'BTI410446766'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  736 BTI410447394 17
# 'BTI410447616'
# 'BTI410447648'
# 'BTI410447700'
# 'BTI410447706'
# 'BTI410447736'
# 'BTI410447770'
# 'BTI410447775'
# 'BTI410447778'
# {4: Timestamp('2019-04-27 00:00:00'), 5: Timestamp('2019-05-29 00:00:00'), 6: Timestamp('2019-06-28 00:00:00'), 7: Timestamp('2019-07-29 00:00:00')}
# *&!@#-->  745 BTI410448557 19
# 'BTI410449140'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  747 BTI410457561 383
# 'BTI410459439'
# 'BTI410461232'
# 'BTI410461665'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  751 BTI410477555 292
# 'BTI410490761'
# 'BTI410499082'
# 'BTI410520027'
# 'BTI410527723'
# 'BTI410534360'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  757 BTI410534924 4
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  758 BTI410535049 298
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  759 BTI410535240 0
# 'BTI410539056'
# 'BTI410546600'
# 'BTI410552602'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  763 BTI410574836 190
# 'BTI410612486'
# 'BTI410623164'
# 'BTI410624383'
# 'BTI410625153'
# 'BTI410625171'
# 'BTI410625436'
# 'BTI410626201'
# 'BTI410627549'
# 'BTI410630299'
# 'BTI410632948'
# 'BTI410633119'
# 'BTI410636213'
# 'BTI410643727'
# 'BTI410655257'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  778 BTI410661510 0
# 'BTI410663199'
# 'BTI410708572'
# 'BTI410708661'
# 'BTI410709137'
# 'BTI410709667'
# 'BTI410732088'
# 'BTI410741291'
# 'BTI410752495'
# 'BTI410758477'
# 'BTI410785245'
# 'BTI410785418'
# 'BTI410791225'
# 'BTI410791432'
# 'BTI410792602'
# 'BTI410797301'
# 'BTI410797328'
# 'BTI410797364'
# 'BTI410805242'
# 'BTI410808283'
# 'BTI410808553'
# 'BTI410813429'
# 'BTI410816567'
# 'BTI410817580'
# 'BTI410823233'
# 'BTI410829254'
# 'BTI410874824'
# 'BTI410877252'
# 'BTI410879829'
# 'BTI410908640'
# 'BTI410914083'
# 'BTI410919149'
# Erro desconhecido:  BTI410943104
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  810 BTI410943104 24
# 'BTI410960560'
# 'BTI410960813'
# 'BTI410971912'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  814 BTI410977542 308
# 'BTI410992992'
# 'BTI410998061'
# 'BTI410998656'
# 'BTI411001477'
# 'BTI411002775'
# 'BTI411017551'
# 'BTI411018191'
# 'BTI411037260'
# 'BTI411040881'
# 'BTI411041996'
# 'BTI411049482'
# 'BTI411049650'
# 'BTI411049976'
# 'BTI411050615'
# 'BTI411050621'
# 'BTI411055611'
# 'BTI411056301'
# 'BTI411069388'
# 'BTI411084203'
# 'BTI411090106'
# 'BTI411090390'
# 'BTI411104371'
# 'BTI411104403'
# 'BTI411104404'
# 'BTI411104676'
# 'BTI411111324'
# 'BTI411127971'
# 'BTI411130873'
# 'BTI411132526'
# 'BTI411143321'
# 'BTI411144435'
# 'BTI411156078'
# 'BTI411170272'
# 'BTI411170916'
# 'BTI411175578'
# {4: Timestamp('2019-04-15 00:00:00'), 5: Timestamp('2019-05-15 00:00:00'), 6: Timestamp('2019-06-17 00:00:00'), 7: Timestamp('2019-07-15 00:00:00')}
# *&!@#-->  850 BTI411177604 25
# 'BTI411182424'
# 'BTI411211738'
# 'BTI411211744'
# 'BTI411211785'
# 'BTI411212227'
# 'BTI411212321'
# 'BTI411212425'
# 'BTI411213212'
# 'BTI411213516'
# 'BTI411214899'
# 'BTI411215671'
# 'BTI411217275'
# 'BTI411217375'
# 'BTI411219398'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  865 BTI411222548 21
# 'BTI411229336'
# 'BTI411239904'
# 'BTI411257425'
# 'BTI411263572'
# 'BTI411267386'
# 'BTI411268706'
# 'BTI411284122'
# 'BTI411287978'
# 'BTI411291344'
# 'BTI411305941'
# 'BTI411309084'
# 'BTI411310428'
# 'BTI411312961'
# 'BTI411313079'
# 'BTI411313652'
# 'BTI411314579'
# 'BTI411316841'
# 'BTI411319857'
# 'BTI411324228'
# 'BTI411324542'
# 'BTI411324780'
# 'BTI411324965'
# 'BTI411331074'
# 'BTI411333926'
# 'BTI411351936'
# 'BTI411355315'
# 'BTI411357066'
# 'BTI411379359'
# 'BTI411380957'
# 'BTI411387076'
# 'BTI411393612'
# 'BTI411394830'
# 'BTI411395964'
# 'BTI411396163'
# 'BTI411401921'
# 'BTI411403495'
# 'BTI411421403'
# 'BTI411444027'
# 'BTI411444519'
# {4: Timestamp('2019-04-27 00:00:00'), 5: Timestamp('2019-05-29 00:00:00'), 6: Timestamp('2019-06-28 00:00:00'), 7: Timestamp('2019-07-29 00:00:00')}
# *&!@#-->  905 BTI411453527 54
# 'BTI411455290'
# 'BTI411456544'
# 'BTI411458040'
# 'BTI411467395'
# 'BTI411482070'
# 'BTI411489044'
# 'BTI411503615'
# 'BTI411503648'
# 'BTI411525654'
# 'BTI411538376'
# 'BTI411556900'
# 'BTI411562406'
# 'BTI411568723'
# 'BTI411568918'
# 'BTI411571524'
# 'BTI411571738'
# 'BTI411573610'
# 'BTI411574404'
# 'BTI411574674'
# 'BTI411577903'
# 'BTI411577905'
# 'BTI411577913'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  928 BTI411580594 3
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  929 BTI411580726 89
# 'BTI411581024'
# 'BTI411587827'
# 'BTI411591661'
# 'BTI411605337'
# 'BTI411605344'
# 'BTI411618932'
# 'BTI411643946'
# 'BTI411650145'
# 'BTI411653674'
# 'BTI411658322'
# 'BTI411659603'
# 'BTI411660129'
# 'BTI411660207'
# 'BTI411663698'
# 'BTI411669006'
# 'BTI411669646'
# 'BTI411673735'
# 'BTI411674552'
# 'BTI411682166'
# 'BTI411696141'
# 'BTI411699442'
# 'BTI411699518'
# 'BTI411703933'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  953 BTI411704725 14
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  954 BTI411704862 22
# 'BTI411712954'
# 'BTI411721498'
# 'BTI411735911'
# 'BTI411740715'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  959 BTI411767210 50
# 'BTI411778130'
# 'BTI411778195'
# 'BTI411788936'
# 'BTI411793194'
# {4: Timestamp('2019-04-27 00:00:00'), 5: Timestamp('2019-05-29 00:00:00'), 6: Timestamp('2019-06-28 00:00:00'), 7: Timestamp('2019-07-29 00:00:00')}
# *&!@#-->  964 BTI411809956 25
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  965 BTI411825785 1
# Erro desconhecido:  BTI411825787
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  966 BTI411825787 27
# 'BTI411828439'
# 'BTI411835674'
# 'BTI411836645'
# 'BTI411837855'
# 'BTI411837862'
# 'BTI411837868'
# 'BTI411837871'
# 'BTI411841597'
# 'BTI411850640'
# 'BTI411851901'
# 'BTI411851975'
# 'BTI411858680'
# 'BTI411876844'
# 'BTI411878714'
# 'BTI411896570'
# {4: Timestamp('2019-04-25 00:00:00'), 5: Timestamp('2019-05-27 00:00:00'), 6: Timestamp('2019-06-26 00:00:00'), 7: Timestamp('2019-07-25 00:00:00')}
# *&!@#-->  982 BTI411921607 18
# 'BTI411924606'
# 'BTI411933703'
# 'BTI411942118'
# 'BTI411947571'
# 'BTI411948877'
# 'BTI411954488'
# 'BTI411967981'
# 'BTI411977363'
# 'BTI411981256'
# 'BTI411985176'
# 'BTI411997135'
# 'BTI411999140'
# 'BTI411999589'
# 'BTI412003978'
# 'BTI412004253'
# 'BTI412005714'
# 'BTI412008818'
# 'BTI412020563'
# 'BTI412026240'
# 'BTI412032861'
# 'BTI412032910'
# 'BTI412032994'
# 'BTI412034251'
# 'BTI412034558'
# 'BTI412058516'
# 'BTI412064656'
# 'BTI412073014'
# 'BTI412097586'
# {4: Timestamp('2019-04-25 00:00:00'), 5: Timestamp('2019-05-27 00:00:00'), 6: Timestamp('2019-06-26 00:00:00'), 7: Timestamp('2019-07-25 00:00:00')}
# *&!@#-->  1011 BTI412100275 488
# 'BTI412101831'
# 'BTI412107283'
# 'BTI412115640'
# 'BTI412122777'
# 'BTI412125961'
# 'BTI412126672'
# 'BTI412128282'
# 'BTI412132010'
# 'BTI412141804'
# 'BTI412148387'
# 'BTI412166217'
# 'BTI412171105'
# 'BTI412173267'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  1025 BTI412209092 116
# 'BTI412209257'
# 'BTI412238650'
# 'BTI412248434'
# 'BTI412261236'
# 'BTI412261240'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  1031 BTI412267689 13
# 'BTI412287198'
# {4: Timestamp('2019-04-27 00:00:00'), 5: Timestamp('2019-05-29 00:00:00'), 6: Timestamp('2019-06-28 00:00:00'), 7: Timestamp('2019-07-29 00:00:00')}
# *&!@#-->  1033 BTI412302780 6
# 'BTI412310803'
# 'BTI412315510'
# 'BTI412320468'
# 'BTI412324356'
# 'BTI412333236'
# 'BTI412333683'
# 'BTI412334338'
# 'BTI412337777'
# 'BTI412341817'
# 'BTI412341821'
# 'BTI412342828'
# 'BTI412343328'
# 'BTI412343693'
# 'BTI412360431'
# 'BTI412363957'
# 'BTI412366206'
# 'BTI412378867'
# 'BTI412400478'
# 'BTI412400712'
# 'BTI412401823'
# 'BTI412407943'
# 'BTI412409501'
# 'BTI412414241'
# 'BTI412426146'
# 'BTI412439097'
# 'BTI412450098'
# 'BTI412450133'
# 'BTI412454738'
# 'BTI412463193'
# 'BTI412479982'
# 'BTI412487479'
# 'BTI412489745'
# 'BTI412498013'
# 'BTI412498435'
# 'BTI412503260'
# 'BTI412508210'
# 'BTI412513352'
# 'BTI412513987'
# 'BTI412516626'
# 'BTI412521573'
# 'BTI412529195'
# 'BTI412530339'
# 'BTI412543797'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  1077 BTI412545359 0
# 'BTI412550064'
# 'BTI412557034'
# 'BTI412569652'
# 'BTI412573094'
# 'BTI412580367'
# 'BTI412582026'
# 'BTI412583303'
# 'BTI412585166'
# 'BTI412588482'
# 'BTI412596505'
# 'BTI412598631'
# 'BTI412613216'
# 'BTI412620507'
# 'BTI412630069'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  1092 BTI412638230 32
# 'BTI412650317'
# 'BTI412650545'
# 'BTI412654556'
# 'BTI412660195'
# 'BTI412660791'
# 'BTI412661967'
# 'BTI412665427'
# 'BTI412667613'
# 'BTI412682149'
# 'BTI412682171'
# {4: Timestamp('2019-04-27 00:00:00'), 5: Timestamp('2019-05-29 00:00:00'), 6: Timestamp('2019-06-28 00:00:00'), 7: Timestamp('2019-07-29 00:00:00')}
# *&!@#-->  1103 BTI412682801 32
# 'BTI412687778'
# 'BTI412691621'
# 'BTI412697837'
# {4: Timestamp('2019-04-27 00:00:00'), 5: Timestamp('2019-05-29 00:00:00'), 6: Timestamp('2019-06-28 00:00:00'), 7: Timestamp('2019-07-29 00:00:00')}
# *&!@#-->  1107 BTI412698296 14
# 'BTI412698548'
# 'BTI412699902'
# 'BTI412704269'
# 'BTI412720711'
# 'BTI412729190'
# 'BTI412729643'
# 'BTI412731515'
# 'BTI412740903'
# 'BTI412745168'
# 'BTI412746480'
# 'BTI412747744'
# 'BTI412760732'
# 'BTI412763482'
# 'BTI412765429'
# 'BTI412770442'
# 'BTI412777619'
# 'BTI412787198'
# 'BTI412792507'
# 'BTI412809804'
# 'BTI412812464'
# 'BTI412814921'
# {4: Timestamp('2019-04-25 00:00:00'), 5: Timestamp('2019-05-27 00:00:00'), 6: Timestamp('2019-06-26 00:00:00'), 7: Timestamp('2019-07-25 00:00:00')}
# *&!@#-->  1129 BTI412824153 2
# 'BTI412824402'
# 'BTI412827190'
# 'BTI412837523'
# 'BTI412840675'
# 'BTI412849650'
# 'BTI412854137'
# 'BTI412876108'
# 'BTI412886498'
# 'BTI412887841'
# 'BTI412888502'
# 'BTI412890957'
# 'BTI412902226'
# 'BTI412908312'
# 'BTI412910671'
# 'BTI412919644'
# 'BTI412931532'
# 'BTI412936602'
# 'BTI412942322'
# 'BTI412946200'
# 'BTI412947537'
# 'BTI412949788'
# 'BTI412956180'
# {4: Timestamp('2019-04-27 00:00:00'), 5: Timestamp('2019-05-29 00:00:00'), 6: Timestamp('2019-06-28 00:00:00'), 7: Timestamp('2019-07-29 00:00:00')}
# *&!@#-->  1152 BTI412967061 3
# 'BTI412989487'
# 'BTI412999202'
# 'BTI413011058'
# 'BTI413011157'
# 'BTI413013430'
# 'BTI413014151'
# 'BTI413017147'
# 'BTI413017446'
# 'BTI413020245'
# 'BTI413036028'
# 'BTI413040099'
# 'BTI413041616'
# 'BTI413043201'
# 'BTI413051244'
# 'BTI413059699'
# 'BTI413059716'
# {4: Timestamp('2019-04-27 00:00:00'), 5: Timestamp('2019-05-29 00:00:00'), 6: Timestamp('2019-06-28 00:00:00'), 7: Timestamp('2019-07-29 00:00:00')}
# *&!@#-->  1169 BTI413068551 226
# 'BTI413081598'
# 'BTI413088656'
# 'BTI413089817'
# 'BTI413100676'
# 'BTI413101001'
# 'BTI413101003'
# 'BTI413106684'
# 'BTI413118545'
# 'BTI413134428'
# 'BTI413138282'
# 'BTI413140055'
# 'BTI413150481'
# 'BTI413159243'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  1183 BTI413166493 18
# 'BTI413182519'
# 'BTI413183167'
# 'BTI413185791'
# 'BTI413194526'
# 'BTI413194887'
# 'BTI413205966'
# 'BTI413206318'
# 'BTI413217777'
# 'BTI413231292'
# 'BTI413235795'
# 'BTI413237651'
# 'BTI413251484'
# 'BTI413257106'
# 'BTI413262127'
# 'BTI413272167'
# 'BTI413286360'
# 'BTI413288244'
# 'BTI413290074'
# 'BTI413297631'
# 'BTI413307692'
# 'BTI413327555'
# 'BTI413328221'
# 'BTI413333763'
# Erro desconhecido:  BTI413335062
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  1207 BTI413335062 45
# 'BTI413340940'
# 'BTI413341557'
# 'BTI413341860'
# 'BTI413348533'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  1212 BTI413350969 3
# 'BTI413354214'
# 'BTI413356793'
# 'BTI413359621'
# {4: Timestamp('2019-04-27 00:00:00'), 5: Timestamp('2019-05-29 00:00:00'), 6: Timestamp('2019-06-28 00:00:00'), 7: Timestamp('2019-07-29 00:00:00')}
# *&!@#-->  1216 BTI413364204 20
# 'BTI413365965'
# 'BTI413375269'
# 'BTI413391165'
# 'BTI413398769'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  1221 BTI413407334 286
# 'BTI413431988'
# 'BTI413447275'
# 'BTI413456564'
# 'BTI413463009'
# 'BTI413467276'
# 'BTI413467535'
# {4: Timestamp('2019-04-27 00:00:00'), 5: Timestamp('2019-05-29 00:00:00'), 6: Timestamp('2019-06-28 00:00:00'), 7: Timestamp('2019-07-29 00:00:00')}
# *&!@#-->  1228 BTI413471703 13
# 'BTI413489927'
# 'BTI413525264'
# 'BTI413543646'
# 'BTI413550659'
# 'BTI413595836'
# 'BTI413614956'
# 'BTI413630799'
# 'BTI413638231'
# 'BTI413639768'
# 'BTI413648141'
# 'BTI413703698'
# 'BTI413719412'
# 'BTI413747184'
# 'BTI413748194'
# 'BTI413748195'
# 'BTI413748201'
# 'BTI413762529'
# 'BTI413791975'
# 'BTI413823971'
# 'BTI413845868'
# 'BTI413860891'
# 'BTI413903245'
# 'BTI413914313'
# 'BTI413917165'
# 'BTI414005967'
# 'BTI414016402'
# 'BTI414022747'
# 'BTI414043326'
# 'BTI414069001'
# 'BTI414088141'
# 'BTI414094425'
# 'BTI414104114'
# 'BTI414104165'
# 'BTI414104184'
# 'BTI414104199'
# 'BTI414104208'
# 'BTI414107726'
# 'BTI414110109'
# 'BTI414126354'
# 'BTI414169793'
# 'BTI414173582'
# 'BTI414173632'
# 'BTI414200316'
# 'BTI414200386'
# 'BTI414208878'
# 'BTI414211948'
# 'BTI414216392'
# 'BTI414259852'
# 'BTI414264258'
# 'BTI414268101'
# 'BTI414270157'
# 'BTI414275381'
# 'BTI414280474'
# 'BTI414283965'
# 'BTI414321322'
# 'BTI414332447'
# 'BTI414345249'
# 'BTI414348405'
# 'BTI414352734'
# 'BTI414355606'
# 'BTI414364201'
# 'BTI414368455'
# 'BTI414370536'
# 'BTI414391923'
# 'BTI414407654'
# 'BTI414409743'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  1295 BTI414412826 6
# 'BTI414425474'
# 'BTI414434392'
# 'BTI414449871'
# 'BTI414473287'
# 'BTI414483137'
# 'BTI414497790'
# 'BTI414581058'
# 'BTI414598812'
# 'BTI414622852'
# 'BTI414636770'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  1306 BTI414658651 521
# 'BTI414660869'
# 'BTI414669322'
# 'BTI414670589'
# 'BTI414688031'
# 'BTI414707375'
# 'BTI414743316'
# 'BTI414760945'
# 'BTI414764435'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  1315 BTI414824799 1
# 'BTI414829376'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  1317 BTI414831145 2
# 'BTI414853710'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  1319 BTI414859200 18
# 'BTI414864145'
# 'BTI414888237'
# 'BTI414912031'
# 'BTI420081926'
# 'BTI420095361'
# 'BTI420117277'
# 'BTI420132880'
# 'BTI420172537'
# 'BTI420186458'
# 'BTI420194513'
# 'BTI420199397'
# 'BTI420201181'
# 'BTI420209121'
# 'BTI420214642'
# 'BTI420220293'
# 'BTI420221583'
# 'BTI420237341'
# 'BTI420240680'
# 'BTI420243710'
# 'BTI420253775'
# 'BTI420253798'
# {4: Timestamp('2019-04-27 00:00:00'), 5: Timestamp('2019-05-29 00:00:00'), 6: Timestamp('2019-06-28 00:00:00'), 7: Timestamp('2019-07-29 00:00:00')}
# *&!@#-->  1341 BTI420264098 12
# 'BTI420292743'
# 'BTI420294226'
# 'BTI420312451'
# 'BTI420318146'
# 'BTI420365185'
# 'BTI420367686'
# 'BTI420373872'
# 'BTI420378374'
# 'BTI420397273'
# 'BTI420404192'
# 'BTI420404532'
# 'BTI420412047'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  1354 BTI420429197 13
# 'BTI420442558'
# 'BTI420452305'
# 'BTI420465568'
# 'BTI420476549'
# 'BTI420481338'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  1360 BTI420482497 20
# 'BTI420486949'
# 'BTI420490980'
# 'BTI420506808'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  1364 BTI420527077 4
# 'BTI420537945'
# 'BTI420540973'
# 'BTI420552199'
# 'BTI420560097'
# 'BTI420560214'
# 'BTI420568586'
# 'BTI420569650'
# 'BTI420575117'
# 'BTI420599566'
# 'BTI420614536'
# 'BTI420622095'
# 'BTI420627632'
# 'BTI420639963'
# 'BTI420676687'
# 'BTI420692980'
# 'BTI420694994'
# 'BTI420716655'
# 'BTI420726904'
# 'BTI420738351'
# 'BTI420750957'
# 'BTI420757768'
# 'BTI420778594'
# 'BTI420840649'
# 'BTI420847270'
# 'BTI420849066'
# 'BTI420861059'
# 'BTI420870569'
# {4: Timestamp('2019-04-26 00:00:00'), 5: Timestamp('2019-05-28 00:00:00'), 6: Timestamp('2019-06-27 00:00:00'), 7: Timestamp('2019-07-26 00:00:00')}
# *&!@#-->  1392 BTI420892281 0
# 'BTI420892596'
# 'BTI420895022'
# 'BTI420901556'
# 'BTI420911422'
# 'BTI420918527'
# 'BTI420967209'
# 'BTI420990204'
# 'BTI420991160'
# 'BTI421004181'
# 'BTI421036646'
# 'BTI421074966'
# 'BTI421100890'
# 'BTI421106759'
# {4: Timestamp('2019-04-25 00:00:00'), 5: Timestamp('2019-05-27 00:00:00'), 6: Timestamp('2019-06-26 00:00:00'), 7: Timestamp('2019-07-25 00:00:00')}
# *&!@#-->  1406 BTI421115262 486
# 'BTI421120273'
# {4: Timestamp('2019-04-27 00:00:00'), 5: Timestamp('2019-05-29 00:00:00'), 6: Timestamp('2019-06-28 00:00:00'), 7: Timestamp('2019-07-29 00:00:00')}
# *&!@#-->  1408 BTI421155328 15
# 'BTI421159055'
# 'BTI421166344'
# 'BTI421177615'
# 'BTI421178725'
# 'BTI421179110'
# 'BTI421193598'
# 'BTI421193919'
# 'BTI421196744'
# 'BTI421197009'
# 'BTI421198154'
# 'BTI421208596'
# 'BTI421210140'
# 'BTI421212233'
# 'BTI421231413'
# 'BTI421248193'
# 'BTI421264249'
# 'BTI421319775'

# %% [markdown]
# l__________________________________________________________________________________________________________________________________________________

# %%
fasfal4 = pload('../../pickles/fasfal4.pkl')

# %%
fasfal3= pload('../../pickles/fasfal3.pkl')

# %%
len(erros), len(emp)
# Out:
# (1332, 94)

# %%
li = [i for i in fasfal4 if i in emp]

# %%
len(li), len(fasfal4)
# Out:
# (0, 61)

# %%
dempt = demp.T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-956b6c144044> in <module>()
# ----> 1 dempt = demp.T
#
# NameError: name 'demp' is not defined

# %%
len(emp), demp.shape

# %%
li2 = [i for i in fasfal4 if i in list(dempt.columns)]

# %%
len(li2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-c13b4ca84192> in <module>()
# ----> 1 len(li2)
#
# NameError: name 'li2' is not defined

# %%
dempt[[*fasfal3]].T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-d5a36da48b04> in <module>()
# ----> 1 dempt[[*fasfal3]].T
#
# NameError: name 'dempt' is not defined

# %% [markdown]
# l__________________________________________________________________________________________________________________________________________________

# %%
demp=pd.DataFrame(index=emp.keys(), data=emp.values(),columns = [5,6,7])

# %%
#demp=demp.dropna().applymap(int)
demp.to_csv('../../outputs/fas_emp_LIGHT.csv')

# %%
demp_porc=pd.DataFrame(index=emp_porc.keys(), data=emp_porc.values(),columns = [5,6,7])
demp_porc=demp_porc.dropna(inplace=True, axis=0).applymap(int)
demp_porc2.to_csv('../../outputs/fas_emp_razão.csv')

# %%
demp_porc2[5].hist()

# %% [markdown]
# ## l_______________________________________________________________________

# %% [markdown]
# ### Leituras faltando -  Memória de massa

# %%
from importlib import reload
reload(mainlib)
reload(of_proc)
from mainlib import fasorial, mm, dframe

m = mm(json_file)
df = dframe(json_file).dateparser

# %%
dmm = {}
for i in ld(MM):
    dmm[i] = pd.read_csv(join(MM,i), sep=';',decimal=',', low_memory=False, index_col = [0], na_values=' ',date_parser = df, parse_dates=[0])
    #dmm[i] = pd.read_csv(join(MM,i), sep=';',decimal=',', low_memory=False, index_col = [0], na_values=' ')
    print(dmm[i].index[dmm[i].shape[0]-1])
    dmm[i].drop(dmm[i].index[dmm[i].shape[0]-1],inplace=True)

# %%
n=0
for k,v in dmm.items():
    n+= v.shape[1]
    print(v.shape)
print(n)

# %%
#Checar se os índices são os mesmos
for n,(k,v) in enumerate(dmm.items()):
    if n == 0:
        a1 = list(v.index)
        continue
    else:
        a2 = list(v.index)
    assert a1==a2

# %% [markdown]
# #####  Montar Dataframe coalizado

# %%
mm = pd.DataFrame()
for k,v in dmm.items():
    mm = pd.concat((mm,v),axis=1)

# %% [markdown]
# ##### Checar vazios

# %% [markdown]
# ## l_______________________________________________________________________

# %% [markdown]
# ### Com troca

# %%
lista.set_index('medidor')

# %%
def get_daterange(lista): return lista.set_index('medidor')[['data_inicio','data_fim']].T.to_dict()

# %%
def multimed(dim):
    '''
    gets from dim, a dict with instalation that have more than one medidor
    '''
    mi1={}
    mi2={}
    erros = []
    for k,v in dim.items():
        if len(v)>1:
            #print(v)
            mi2[k] = v
        elif len(v) == 1:
            mi1[k] = v
        else:
            erros.append(k)
    return mi1, mi2, erros

# %%
def sort_by_daterange(dici):
    '''
    gets a dict whose values are tuples (initial date, end date)
    returns list of dict keys sorted by initial date
    '''
    idate2key = {v['data_inicio']:k for k,v in dici.items()}
    sk = sorted(idate2key.keys())
    sorted_keys = []
    for j in idate2key:
        sorted_keys.append(idate2key[j])
    return sorted_keys

# %%
def concat_mm(mm,dici,sorted_keys):
    '''
    input:
        mm:
            dataframe with mass memory
        dici:
            dict {mm: (initial date, end date)}
        sorted_keys:
            list [ dici keys sorted by initial date]
    '''
    insta_mm = pd.DataFrame()
    dici_output_mm = {}
    for nn in sorted_keys:
        strmed = '0'+str(nn)
        insta_mm = pd.concat((insta_mm, mm[strmed][dici[nn]['data_inicio']:dici[nn]['data_fim']]))
    return insta_mm

# %%
def count_null(dici_df_mm): return {k: v.iloc[:,0].isnull().sum() for k,v in dici_df_mm.items()}

# %%
def concat_multimed_mm(mm, lista, dim):
    mi1, mi2, _ =  multimed(dim)
    datmi = get_daterange(lista)
    dici_df_mm = {}
    erros=[]
    for i in mi2:
        med2dates = {m:datmi[int(m)] for m in mi2[i]}
        #print(a)
        sorted_keys = sort_by_daterange(med2dates)     
        try:
            dici_df_mm[i]=concat_mm(mm,med2dates,sorted_keys)
        except Exception as e:
            print(e)
            erros.append(i)
    dnull = count_null(dici_df_mm)
    return dici_df_mm,dnull,  erros

# %%
get_daterange(lista)

# %%
lc = lista[['instalacao', 'medidor']]
dim = lc.groupby(['instalacao'])['medidor'].apply(list).to_dict()

# %%
omi2, dnull2, erros2 = concat_multimed_mm(mm, lista, dim)

# %%
len(omi2), len(dnull2), len(erros2)

# %% [markdown]
# -----

# %% [markdown]
# ### Sem troca

# %%
dim2 = {}
for k,v in dim.items():
    if v!=['MEDIDOR']:
        dim2[k] = v

# %%
mi1, mi2, _ =  multimed(dim2)

# %%
med1 = ['0' + str(i[0]) for i in mi1.values()]

# %%
mst = mm[med1]

# %%
mst.isnull().sum().to_dict()

# %% [markdown]
# ### Separar por meses

# %%
 mi1, mi2, erros = multimed(dim)

# %% [raw]
# dmi = pload('../../pickles/dmi.pkl')

# %% [markdown]
# ##### Trocar medidor por instalação no dataframe

# %%
dmi = {}
for k,v in dim.items():
    for v1 in v:
        dmi[v1] = k

# %%
len(dmi), len(dim)

# %%
icols = [dmi[(int(m))] for m in mst.columns]
len(icols), len(mst.columns)
mst.columns = icols

# %% [markdown]
# ##### Criar lista aumentada para dias de leitura

# %%
ldl = lista[[4,5,6,7]].T.to_dict()
ldl2={}
for k,v in ldl.items():
    ldl2[k] = [pd.Timestamp('1900-01-01'), v[4], v[5], v[6], v[7], pd.Timestamp('2100-12-31')]

# %%
dmst = mst.to_dict()

# %% [markdown]
# ##### Dicionário de dataframes com troca

# %%
omi3 = omi2.copy()
for k,v in omi3.items():
    omi3[k] = v.sort_index(ascending=True)

# %% [markdown]
# ##### DataFrame sem troca

# %%
dfst = {} 
for n,(k,v) in enumerate(dmst.items()):
    print(n,end=' ')
    dfst[k] = pd.DataFrame(index = v.keys(), data = v.values())

# %%
dl={}
for i in dim:
    if i in omi3:        
        dl[i] = {}
        for n,d in enumerate(ldl2[i][1:]):
            #print( max(pd.to_datetime(ldl2[i][n].date()), omi2[i].index[0]) ,'====', min(pd.to_datetime(ldl2[i][n+1]), omi2[i].index[-1]))
            try:
                dl[i][n] = omi3[i][max(pd.to_datetime(ldl2[i][n].date()), pd.to_datetime(omi2[i].index[0])) : min(pd.to_datetime(ldl2[i][n+1]), pd.to_datetime(omi2[i].index[-1]))]
            except Exception as e:
                print(e)
            #dl[i][n] = omi2[i][  pd.to_datetime(ldl2[i][n+1]):pd.to_datetime(ldl2[i][n])]
    elif i in dfst:
        dl[i] = {}
        for n,d in enumerate(ldl2[i][1:]):
            try:
                #print(dmst[i])
                print(max(pd.to_datetime(ldl2[i][n].date()), pd.to_datetime(dfst[i].index[0])))
                print(min(pd.to_datetime(ldl2[i][n+1]), pd.to_datetime(dfst[i].index[-1])))
                dl[i][n] = dfst[i].loc[max(pd.to_datetime(ldl2[i][n].date()), pd.to_datetime(dfst[i].index[0])) : min(pd.to_datetime(ldl2[i][n+1]), pd.to_datetime(dfst[i].index[-1])),:]
            except Exception as e:
                print('--->', e)

# %%
tnull = {}
for k,v in dl.items():
    tnull[k] = {}
    for k1, v1 in v.items():
        tnull[k][k1]= v1.iloc[:,0].isnull().sum()

# %%
out_df = pd.DataFrame(tnull).T

# %% [markdown]
# ###### Escolher

# %%
#out_name = '../../outputs/mm_vazios.csv'
out_name = '../../outputs/mm_vazios_3.csv'

# %%
out_df.to_csv(out_name)

# %%
lf = [
'BTI420861059',
'BTI410018634',
'BTI411682166',
'BTI411605337',
'BTI410663199',
'BTI420199397',
'BTI411213516',
'BTI412463193',
'BT2A413075265',
'BT2A430044984',
'BT2A414211457',
'BT2A412744882',
'BT2A420384317',
'BT2A414833048',
'BT2A421290565',
'BT2A410217918',
'BT2A421303010',
'BT2A413512843',
'BT2A413419789',
'BT2A410774805',
'BT2A420231449',
'BT2A420075911',
'BT2A413160639',
'BT2A412438190',
'BT2A413785709',
'BT2A411518477',
'BT2A413611209',
'BTI400376108',
'BTI410461665',
'BTI410412319',
'BTI410360627',
'BTI410292571',
'BTI413333763',
'BTI412248434',
'BTI410269345',
'BTI413638231',
'BTI400094048',
'BTI412479982',
'BTI410797301',
'BTI414391923',
'BTI410119113',
'BTI411735911',
'BTI420895022',
'BTI412582026',
'BTI414104114',
'BTI410005110',
'BTI414743316',
'BTI410361215',
'BTI420552199',
'BTI413106684',
'BTI411482070',
'BTI412827190',
'BTI412809804',
'BTI411144435',
'BTI410643727',
'BTI411263572',
'BTI414483137',
'BTI410360258',
'BTI420132880',
'BTI410298633',
'BTI420312451'
]

# %% [markdown]
# ------

# %%
df = pd.concat( (pd.read_csv('mm_vazios.csv'), pd.read_csv('mm_vazios_2.csv')))
df.set_index('Unnamed: 0', drop=True, inplace=True)
df.to_csv('mm_vazios_1442.csv')

# %% [markdown]
# ## l_______________________________________________________________________

# %% [markdown]
# #### De cinco em cindo dias

# %%
tnull = {}
for n,(k,v) in enumerate(dl.items()):
    tnull[k] = {}
    for k1, v1 in v.items():
        tnull[k][k1]= list(v1.resample('5d').apply(lambda x:  x.isnull().sum()).to_dict().values())[0]
        #a =  list(v1.resample('5d').apply(lambda x:  x.isnull().sum()).to_dict().values())[0]

# %%
x2 = {}
for k,v in tnull.items():
    x2[k] = {}
    for k1,v1 in v.items():
        for n,(k2, v2) in enumerate(v1.items()):
            x2[k][str(k1) + '_' + str(n)] = v2

# %%
x3 = pd.DataFrame(x2)

# %%
meses = {'0': 'Abril', '1':'Maio', '2':'Junho', '3':'Julho', '4':'Agosto', '5':'Setembro'}

# %%
cinquena = pd.Series(x3.index).apply(lambda x: x.split('_')[1]).values

# %%
mes = pd.Series(x3.index).apply(lambda x: meses[x.split('_')[0]]).values

# %%
x3.insert(loc=0, column='mes', value = mes)

# %%
x3.insert(loc=1, column='cinquena', value = cinquena)

# %%
x3.to_csv('../../outputs/mm_falta_5dias.csv')

# %% [markdown]
# ## l_______________________________________________________________________
