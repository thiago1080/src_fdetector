# %% [markdown]
# #### Análise 01082019

# %%
import pandas as pd

# %%
# !ls ../data/
# Out:
# 20190628-Analise_cruzada_resultado redes neurais X Campoxlsx-E2.csv
# LISTA BTI_BT200_1000 Casos estudo RN_Resultados CCM.xlsx
# README.txt
# groundtruth.csv

# %%
data = pd.read_csv('../data/ancruz.csv', sep=';')

# %% [markdown]
# #### Falsos positivos

# %%
data.head()
# Out:
#   Ponto de medicao   Análise              Retorno de campo  \
# 0     BTI400085391  Envio P0                 AREA DE RISCO
# 1     BTI413006417  Envio P0  CLIENTE DESLIGADO OU CORTADO
# 2     BTI413791784  Envio P0  CLIENTE DESLIGADO OU CORTADO
# 3     BTI400099015  Envio P0             DEFEITO SEM PERDA
# 4     BTI414427885  Envio P0           DEFEITO GEROU PERDA
#
#   Diagnóstico Redes neurais Severidade fasorial Severidade perfil Morro  \
# 0                     Baixa                   1                 0     0
# 1                      Alta                   2                 0     X
# 2                      Alta                   2                 0     0
# 3               Muito baixa                   0                 0     0
# 4                      Alta                   2                 0     0
#
#   Degrau Falta dados\nMM Falta dados\nFasorial Diagnóstico Fluxo  \
# 0      0            3624                   256          xDEFEITO
# ...

# %%
data.loc[:, 'Análise'].value_counts()
# Out:
# NA - Nada apurado          707
# FORA DA MATRIZ             672
# Envio P0                   313
# NA - ALR Característico      3
# Name: Análise, dtype: int64

# %%
data[data['Análise']=='NA - Nada apurado'][data['Diagnóstico Redes neurais']=='Alta']
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#      Ponto de medicao            Análise Retorno de campo  \
# 249      BTI410613629  NA - Nada apurado              NaN
# 250      BTI410627580  NA - Nada apurado              NaN
# 260      BTI400075396  NA - Nada apurado              NaN
# 261     BT2A410905316  NA - Nada apurado              NaN
# 263      BTI411136791  NA - Nada apurado              NaN
# 267      BTI410802501  NA - Nada apurado              NaN
# 268      BTI411063373  NA - Nada apurado              NaN
# 269      BTI411879012  NA - Nada apurado              NaN
# 270      BTI400119377  NA - Nada apurado              NaN
# 273      BTI410581327  NA - Nada apurado              NaN
# 276      BTI411414234  NA - Nada apurado              NaN
# ...
