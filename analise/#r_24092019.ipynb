# %% [markdown]
# #### Reunião 24092019
# #### Problema: alguns fasoriais estão com diagnóstico de redes neurais mas não estão na lista de análise de dados faltantes.}

# %%
import sys
import os
from os.path import join
from os import listdir as ld
from pathlib import Path
sys.path.append(join(Path(os.getcwd()).parent, 'lib'))

# %%
import A_base as ab
# Out:
# Using TensorFlow backend.

# %%
from of_proc import pload, get_list, dicts
import pandas as pd

# %% [markdown]
# -------------------------------

# %% [markdown]
# ##### Diag_dados -> não é Defeito falta de dados ---- faltantes fasorial -> pendente

# %%
LISTA = '/home/ubuntu/data/data/maio_2019/setembro/lista-cad-pnt-20190820.csv'
LISTAF = '/home/ubuntu/data/data/maio_2019/setembro/lista-cad-pnt-20190820-faltantes.csv'
PATH_FAS = '/home/ubuntu/data/data/maio_2019/setembro/fas-sep'

# %%
from mainlib import dframe

# %%
lcols = dframe().data['lista2']['columns']

# %%
l1 =pd.read_csv(LISTA, names = lcols)

# %%
l2 = pd.read_csv(LISTAF, names = lcols)

# %%
l = pd.concat( ( l1,l2)).drop(index =0)

# %%
l
# Out:
#           cliente    instalacao    medidor data_inicio    data_fim lote  \
# 1    BTI400073539  BTI400073539    8548867  25/04/2018  11/05/2099  06*
# 2    BTI400077054  BTI400077054    8433819  04/05/2015  01/09/2099  18*
# 3    BTI400085863  BTI400085863    8550649  26/06/2019  02/07/2099  16*
# 4    BTI400085863  BTI400085863    8027999  30/10/2014  26/06/2019  18*
# 5    BTI400086150  BTI400086150    9756571  12/08/2019  16/08/2099  01*
# 6    BTI400086150  BTI400086150    8025539  02/12/2014  11/08/2019  01*
# 7    BTI400086681  BTI400086681    8432330  15/06/2015  12/08/2019  03*
# 8    BTI400086681  BTI400086681    9756606  12/08/2019  14/08/2099  03*
# 9    BTI400091995  BTI400091995    8553177  09/05/2019  14/05/2099  18*
# 10   BTI400091995  BTI400091995    8026029  18/07/2014  08/05/2019  18*
# 11   BTI400095370  BTI400095370    8552766  19/07/2016  31/12/2099  07*
# 12   BTI400113018  BTI400113018    8552488  01/02/2017  22/03/2099  12*
# ...

# %%
#Lista montada artesanalmente a partir da planilha excel devolvida pela análise
fasfal3 = [
'BTI411213516',
'BT2A430044984',
'BT2A414211457',
'BT2A412744882',
'BT2A414833048',
'BT2A413512843',
'BT2A413160639',
'BTI410461665',
'BTI410412319',
'BTI410360627',
'BTI410292571',
'BTI412248434',
'BTI410797301',
'BTI414391923',
'BTI411735911',
'BTI414104114',
'BTI413106684',
'BTI410643727',
'BTI420132880',
'BTI420312451'
]

# %%
fasfal4 =['BTI420861059',
'BTI410018634',
'BTI411682166',
'BTI411605337',
'BTI410663199',
'BTI420199397',
'BTI411213516',
'BTI412463193',
'BT2A413075265',
'BT2A430044984',
'BT2A414211457',
'BT2A412744882',
'BT2A420384317',
'BT2A414833048',
'BT2A421290565',
'BT2A410217918',
'BT2A421303010',
'BT2A413512843',
'BT2A413419789',
'BT2A410774805',
'BT2A420231449',
'BT2A420075911',
'BT2A413160639',
'BT2A412438190',
'BT2A413785709',
'BT2A411518477',
'BT2A413611209',
'BTI400376108',
'BTI410461665',
'BTI410412319',
'BTI410360627',
'BTI410292571',
'BTI413333763',
'BTI412248434',
'BTI410269345',
'BTI413638231',
'BTI400094048',
'BTI412479982',
'BTI410797301',
'BTI414391923',
'BTI410119113',
'BTI411735911',
'BTI420895022',
'BTI412582026',
'BTI414104114',
'BTI410005110',
'BTI414743316',
'BTI410361215',
'BTI420552199',
'BTI413106684',
'BTI411482070',
'BTI412827190',
'BTI412809804',
'BTI411144435',
'BTI410643727',
'BTI411263572',
'BTI414483137',
'BTI410360258',
'BTI420132880',
'BTI410298633',
'BTI420312451'
]

# %%
fasfal5 = [
'BTI413335062',
'BTI410295093',
'BTI410943104',
'BTI410332762',
'BTI420429197',
'BTI412267689',
'BTI420482497',
'BTI420527077',
'BTI411825787',
'BT2A410457345',
'BT2A414505502',
'BT2A421331411',
'BT2A410315584',
'BT2A412758021',
'BT2A414610425',
'BT2A410564455',
'BT2A420103194',
'BT2A411136693',
'BT2A410711734',
'BT2A411580720',
'BT2A414583015',
'BT2A411453683',
'BT2A411063546',
'BT2A413776819',
'BT2A413528302',
'BT2A410661427',
'BT2A412377295',
'BT2A413668708',
'BT2A412541235',
'BT2A414566994',
'BT2A412008091',
'BT2A414526295',
'BT2A412538674',
'BT2A420605940',
'BT2A411062569',
'BT2A413443943',
'BT2A410444087',
'BT2A420613277',
'BT2A410496740',
'BT2A420705641',
'BT2A420475716',
'BT2A410574718',
'BTI411809956',
'BTI414831145',
'BTI413407334',
'BTI410477555',
'BTI411453527',
'BTI413364204',
'BTI412698296',
'BTI410112094',
'BTI412638230',
'BTI413350969',
'BTI412100275',
'BTI410457561',
'BTI412967061',
'BTI414859200',
'BTI410006988',
'BTI413068551',
'BTI410006819',
'BTI411825785',
'BTI410359670',
'BTI411222548',
'BTI412209092',
'BTI420264098',
'BTI410448557',
'BTI412302780',
'BTI414658651',
'BTI410226095',
'BTI412545359',
'BTI410534924',
'BTI410361683',
'BTI412682801',
'BTI410574836',
'BTI413166493',
'BTI410535049',
'BTI421155328',
'BTI410447394',
'BTI410661510',
'BTI413471703',
'BTI420892281',
'BTI411704862',
'BTI412824153',
'BTI411921607',
'BTI411767210',
'BTI414412826',
'BTI411580594',
'BTI414824799',
'BTI411704725',
'BTI410977542',
'BTI421115262',
'BTI411580726',
'BTI410535240'
]

# %% [markdown]
# -------------------------------

# %%
a = [i for i in fasfal5 if i not in fasfal4]
len(a)
# Out:
# 92

# %%
a = [i for i in fasfal4 if i not in fasfal5]
len(a)
# Out:
# 61

# %%
fasfal4 = fasfal5

# %% [markdown]
# -------------------------------

# %%
from of_proc import pdump

# %%
pdump(fasfal4,'../../pickles/fasfal4.pkl')

# %%
pdump(fasfal3,'../../pickles/fasfal3.pkl')

# %% [markdown]
# -------------------------------

# %% [markdown]
# #### Verificar

# %% [markdown]
# ##### Verificar se faltantes estão na lista 1

# %%
l[l['cliente'] =='BTI420861059']
# Out:
#           cliente    instalacao  medidor data_inicio    data_fim lote  \
# 188  BTI420861059  BTI420861059  8176303  23/11/2015  31/12/2099  09*
#
#                        ssn           4           5           6           7  \
# 188  8,95511804370004E+019  16/04/2019  16/05/2019  18/06/2019  16/07/2019
#
#                       troca
# 188  1-Sem troca de medidor

# %%
#l = pd.read_csv(LISTA).drop(0)
lo = [i for i in fasfal4 if i  in list(l['cliente'])]
len(lo)
# Out:
# 92

# %% [markdown]
# ##### estão todos

# %% [markdown]
# l_________________________________________________________________________________________

# %% [markdown]
# ##### Verificar se faltantes estão na lista 2

# %% [raw]
# l2 = pd.read_csv(LISTAF)
# lo2 = [i for i in fasfal4 if i  in list(l2['CLIENTE'])]
# len(lo2)

# %% [markdown]
# ##### nenhum faltante na lista 2

# %% [markdown]
# l_________________________________________________________________________________________

# %% [markdown]
# ##### Verificar se faltantes estão entre os arquivos separados

# %%
fl = [i.split('.')[0] for i in ld(PATH_FAS)]

# %%
lo2  = [i for i in fasfal4 if i  in fl]
len(lo2)
# Out:
# 92

# %% [markdown]
# ##### Todos faltantes estão presentes entre os arquivos separados

# %% [markdown]
# l_________________________________________________________________________________________

# %% [markdown]
# ##### Verificar se faltantes estão na lista ddirs_fas

# %%
ddirs_fas = pload('../../pickles/ddirs_fas.pkl')
lo3  = [i for i in fasfal4 if i  in list(ddirs_fas.keys())]
len(lo3)
# Out:
# 0

# %% [markdown]
# l_________________________________________________________________________________________

# %%
l.head()
# Out:
#         cliente    instalacao  medidor data_inicio    data_fim lote  \
# 1  BTI400073539  BTI400073539  8548867  25/04/2018  11/05/2099  06*
# 2  BTI400077054  BTI400077054  8433819  04/05/2015  01/09/2099  18*
# 3  BTI400085863  BTI400085863  8550649  26/06/2019  02/07/2099  16*
# 4  BTI400085863  BTI400085863  8027999  30/10/2014  26/06/2019  18*
# 5  BTI400086150  BTI400086150  9756571  12/08/2019  16/08/2099  01*
#
#                      ssn           4           5           6           7  \
# 1  8,95511802260003E+019  11/04/2019  13/05/2019  13/06/2019  11/07/2019
# 2  8,95511804370003E+019  29/04/2019  30/05/2019  29/06/2019  30/07/2019
# 3  8,95511802260003E+019  26/04/2019  28/05/2019  27/06/2019  26/07/2019
# 4                    NaN  26/04/2019  28/05/2019  27/06/2019  26/07/2019
# 5  8,95511802260002E+019  04/04/2019  06/05/2019  06/06/2019  04/07/2019
#
#                     troca
# 1  1-Sem troca de medidor
# 2  1-Sem troca de medidor
# 3  2-Com troca de medidor
# ...

# %% [markdown]
# l_________________________________________________________________________________________

# %%
oi = pload('../../pickles/o_instas.pkl')

# %%
loi = [i for i in fasfal4 if i in oi.keys()]

# %% [markdown]
# ### Conclusão.
# #### Tem os arquivos, tem na lista. Ocorreu um erro ao passar da lista para o ddirs_fas

# %%
import collections

# %%
from mainlib import dframe

# %%
lcols = dframe().data['lista2']['columns']

# %%
LISTA_CAD = get_list()
#LISTA_CAD.df = pd.read_csv(LISTA, names = lcols).drop(0)
LISTA_CAD.df = l

# %%
o_i_normal = collections.OrderedDict(sorted(LISTA_CAD.mes_days(troca=False).items()))
o_i_troca = collections.OrderedDict(sorted(LISTA_CAD.mes_days(troca=True).items()))
o_instas =  collections.OrderedDict(sorted({**o_i_normal, **o_i_troca}.items()))

# %%
ln = [i for i in fasfal4 if i  in list(o_i_normal.keys())]
len(ln)
# Out:
# 89

# %%
li = [i for i in fasfal4 if i  in list(o_instas.keys())]
len(li)
# Out:
# 92

# %%
lt = [i for i in fasfal4 if i  in list(o_i_troca.keys())]
len(lt)
# Out:
# 3

# %%
def get_files_4(nomes, dim,  CAMINHO):
    not_found = []
    dif = {}
    for i in nomes:
        if i in dim:
            tmp_list = []
            search = ab.search_list_2(str(i),os.listdir(CAMINHO))
            if search:
                dif[i] = search
            else:
                not_found.append(i)                
    return dif, not_found

# %%
dim, dmi = dicts(LISTA_CAD)

# %%
dfiles_fas, nf_fas= get_files_4(list(o_instas.keys()), dim,  PATH_FAS)

# %%
ddirs_fas = {k:join(PATH_FAS,v) for k,v in dfiles_fas.items()}

# %%
len(ddirs_fas), len(dfiles_fas), len(o_instas), len(nf_fas)
# Out:
# (1426, 1426, 1444, 18)

# %%
lf = [i for i in fasfal4 if i  in list(dfiles_fas.keys())]
len(lf)
# Out:
# 92

# %%
ld = [i for i in fasfal4 if i  in list(ddirs_fas.keys())]
len(ld)
# Out:
# 92

# %%
pdump(ddirs_fas, '../../pickles/ddirs_fas.pkl')

# %%
pdump(l, '../../pickles/lista_cad.pkl')

# %%
pdump(fasfal5, '../../pickles/fasfal5.pkl')
